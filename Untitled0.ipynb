# %%
def working_with_data(p):
  df = pd.read_csv(p)
  discrete_values = [0,1]
  df = df.loc[:, df.columns!='Отметка времени']
  for column in data.drop('Кофе или чай?', axis=1):
    df[column] = df[column].fillna(0)
    df[column] = df[column].astype('category')
    df[column] = df[column].cat.codes
    df[column] = (df[column] - df[column].min())/(df[column].max() - df[column].min())
  return df.round(2)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %matplotlib inline
data = working_with_data('data.csv')
data.head(20)
data.columns
scaler = StandardScaler()
data_drop = data.drop('Кофе или чай?', axis=1)
scaler.fit(data_drop)
scaled_features = scaler.transform(data_drop)
print(scaled_features)
scaled_data = pd.DataFrame(scaled_features, columns = data_drop.columns)
x = scaled_data
y = data['Кофе или чай?']
x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x, y, test_size = 0.3)
model = KNeighborsClassifier(metric='euclidean', n_neighbors = 3, weights='uniform')
model.fit(x_training_data, y_training_data)
predictions = model.predict(x_test_data)
#print(x_test_data)
print(classification_report(y_test_data, predictions))
# Out:
# [[ 0.41403934  1.25888149 -0.92932038  0.45374261 -2.20389266  1.55456318
#   -1.87653103 -1.86515465 -0.65491378]
#  [ 0.41403934 -0.65275337 -0.92932038  0.45374261  0.45374261 -0.64326752
#   -3.11504151  0.44856318 -0.65491378]
#  [ 0.41403934 -0.65275337  1.07605517  0.45374261  0.45374261  1.55456318
#    0.63802055 -1.53886111 -0.65491378]
#  [ 0.41403934  1.25888149  1.07605517  0.45374261  0.45374261  1.55456318
#    0.63802055  1.10115026 -0.65491378]
#  [-2.41522946  1.25888149 -0.92932038  0.45374261  0.45374261 -0.64326752
#    0.63802055  1.10115026  0.33293276]
#  [ 0.41403934 -0.65275337 -0.92932038  0.45374261  0.45374261  1.55456318
#   -0.60048993  1.10115026  2.33856058]
#  [ 0.41403934 -0.65275337 -0.92932038 -2.20389266 -2.20389266  1.55456318
#   -3.11504151 -0.2040239   1.35071404]
#  [-2.41522946  1.25888149  1.07605517  0.45374261  0.45374261  1.55456318
#    0.63802055 -1.53886111 -0.65491378]
# ...
